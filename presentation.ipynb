# %% [markdown]
# ![Cliet-Server](client_server.png)

# %%
from django.http import HttpResponse

def index(request):
    return HttpResponse("<html><body>Привет</body></html>") # -> str
    return "<html><body>Привет</body></html>"

# %%
# !curl -v http://example.com/
# Out:
# *   Trying 93.184.216.34:80...
# * Connected to example.com (93.184.216.34) port 80 (#0)
# > GET / HTTP/1.1
# > Host: example.com
# > User-Agent: curl/7.84.0
# > Accept: */*
# >
# * Mark bundle as not supporting multiuse
# < HTTP/1.1 200 OK
# < Accept-Ranges: bytes
# < Age: 433948
# < Cache-Control: max-age=604800
# < Content-Type: text/html; charset=UTF-8
# < Date: Thu, 06 Oct 2022 07:23:50 GMT
# < Etag: "3147526947"
# < Expires: Thu, 13 Oct 2022 07:23:50 GMT
# < Last-Modified: Thu, 17 Oct 2019 07:18:26 GMT
# < Server: ECS (nyb/1D1B)
# < Vary: Accept-Encoding
# < X-Cache: HIT
# < Content-Length: 1256
# <
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
# ...

# %%
# !curl https://svatky.adresa.info/json?date=0710
# Out:
# [{"date":"0710","name":"Justýna"}]

# %%
# !curl --output - https://cataas.com/cat
# Out:
# ����JFIFHH��LExifMM*�i�� X��8Photoshop 3.08BIM8BIM%��ُ��	���B~��C
# ���l�fK�kte툽����~��JE �f��n��ɋ�ivܕ�Qn�Sf�Lc�ok,�k�^���[��k6e�1�:��"�c*�DPt<ƫ>"*�0�f�IѩS�*`f:]�?�t�HͣEL'�6�AБ���E����}��Ł-f��6sF�o�5��(��zT6��hQJ�/#P" 4D�M	��/d�ܹ8�9I��h�ai���6S���Z�tIzΣJ�E�8�'Bh�&V�4b�l���#m�3��g&?έ�4ʮ��6x�3��k�f���*�ޣ���"�'b+l1h�H��̲�<eKj'0��-i
# �,�¬ɡ�#��d�ģ�
# *L�����@�ung��jz_S�O1���+1ʡ$`iPx�&g��_TJA��K԰�(�4*Ŝ�.�j��%i�$K.lْ�q`a�t�0$���%بd��g�h���<̻��7�Y7rb}����1:���2�T0	�&�9�����P�i�q��D#b�<M*-"ec�*F�9$���M�h���eR���u�&�6(x�y�K�:���d1�hz�(�î���<eg#�ѧL$4:�
# 5�.,��M��w�u��w�����g�i�yP!�hN�}K�IH2[05��}L�85ΦR�l^�`]Ȁw2(�-���RƂ�1��N�;�(�"AXۋXa��<�#�l����*���9PȦ����5���cq0�M��)�B-s@���@��)�i�_�j"kcR8�rǬ�&�)Uz�Ƨ;��C4��?R�D�:��ڝxZ(j��(Ћ+�O�5�v& �����>`#�$3e�1G����y����!�F�_��0��f��1��ܸH���I��ī��M���@=�O3lEl}Lf�M�~b�?2,���Y�攀m�2Z�"�g�d�7?ffE��=�h��������-�E���*4K`I�fQ��R7<�b]�߈#d5�(�Q��632l;2�I��@ه�D�Z�
# ...

# %% [markdown]
# [Почитать про HTTP](https://habr.com/ru/post/215117/?ysclid=l8wqh9dldi810255526)
#
# давайте напишем свою программу, которая будет принимать HTTP-запросы и что-нибудь возвращать!

# %%
# !./my_django.py
# Out:
# Connected by ('127.0.0.1', 33346)
# '/etc/passwd'
# 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
